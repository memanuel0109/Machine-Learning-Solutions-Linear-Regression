# %%
import pandas as pd
import folium

df = pd.read_csv('../Datasets/combined_cluster.csv', index_col=0)

chicago_map = folium.Map(location=[41.8781,-87.6298], tiles="CartoDB dark_matter")

colors = ['red', 'orange', 'darkgreen', 'lightgreen',
          'green', 'blue', 'darkblue', 'purple',
          'darkred', 'lightred', 'beige', 'lightgray',
          'pink']

for x, y, price, value in df.values:
    for index, color in enumerate(colors):
        if value == index:
            c = colors[index]
        
    folium.Marker(location=[x,y],
                  icon=folium.Icon(color=c,icon_color='white', icon='home'),
                  popup=price).add_to(chicago_map)

display(chicago_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## color to region key
#
# - region 0 = red
# - region 1 = orange
# - region 2 = dark green
# - region 3 = light green
# - region 4 = green
# - region 5 = blue
# - region 6 = dark blue
# - region 7 = purple
# - region 8 = dark red
# - region 9 = pink
# - region 10 = beige
# - region 11 = light gray

# %%
! jupyter nbconvert --to html Chicago_Map.ipynb
# Out:
# [NbConvertApp] Converting notebook Chicago_Map.ipynb to html
# [NbConvertApp] Writing 1587350 bytes to Chicago_Map.html
